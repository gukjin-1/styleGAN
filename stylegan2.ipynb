# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# %cd /content/
# !git clone https://github.com/dvschultz/stylegan2-ada.git
# !mkdir downloads
# !mkdir datasets
# Out:
# /content
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 364, done.
# remote: Total 364 (delta 0), reused 0 (delta 0), pack-reused 364
# Receiving objects: 100% (364/364), 56.17 MiB | 44.76 MiB/s, done.
# Resolving deltas: 100% (197/197), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_name = "지브리"

# %%
import zipfile
path = "/content/drive/MyDrive/LKJ/"
dataset = dataset_name + ".zip"
local_path = "/content/"
file_name = path + dataset
with zipfile.ZipFile(file_name, 'r') as zip:
   #zip.printdir()
   print('Extracting all the files now...') 
   zip.extractall(local_path) 
   print('Done!')
# Out:
# Extracting all the files now...
# Done!

# %%
import os
import glob
from PIL import Image

files = glob.glob('/content/지브리/*.jpg')

for f in files:
    img = Image.open(f)
    img = img.convert('RGB')
    img_resize = img.resize((int(256), int(256)))
    title, ext = os.path.splitext(f)
    # img_resize.save(title + '_half' + ext)
    img_resize.save(title + ext)

# %%
# %cd /content/

#update this to the path to your image folder
dataset_folder_name = '지브리' # name of zip file may be different from folder name it extracted to
dataset_path = "/content/" + dataset_folder_name

#you don't need to edit anything here
# %cd /content/stylegan2-ada
# !python dataset_tool.py create_from_images /content/datasets/{dataset_name} {dataset_path}
# Out:
# /content
# /content/stylegan2-ada
# Loading images from "/content/지브리"
# Creating dataset "/content/datasets/지브리"
# dataset_tool.py:97: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 496 images.

# %%
# !pip uninstall numpy
# !pip install numpy==1.16.4
# Out:
# Found existing installation: numpy 1.21.6
# Uninstalling numpy-1.21.6:
#   Would remove:
#     /usr/bin/f2py
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.7
#     /usr/local/lib/python3.7/dist-packages/numpy-1.21.6.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libgfortran-2e0d59d6.so.5.0.0
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libopenblasp-r0-2d23e62b.3.17.so
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libquadmath-2d0c479f.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/numpy/*
# Proceed (y/n)? y
#   Successfully uninstalled numpy-1.21.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy==1.16.4
#   Downloading numpy-1.16.4-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 4.9 MB/s
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lucid 0.3.10 requires umap-learn, which is not installed.
# tensorflow 1.15.2 requires gast==0.2.2, but you have gast 0.5.3 which is incompatible.
# xarray 0.20.2 requires numpy>=1.18, but you have numpy 1.16.4 which is incompatible.
# xarray-einstats 0.2.2 requires numpy>=1.21, but you have numpy 1.16.4 which is incompatible.
# tables 3.7.0 requires numpy>=1.19.0, but you have numpy 1.16.4 which is incompatible.
# scikit-image 0.18.3 requires numpy>=1.16.5, but you have numpy 1.16.4 which is incompatible.
# pywavelets 1.3.0 requires numpy>=1.17.3, but you have numpy 1.16.4 which is incompatible.
# pyerfa 2.0.0.1 requires numpy>=1.17, but you have numpy 1.16.4 which is incompatible.
# pyarrow 6.0.1 requires numpy>=1.16.6, but you have numpy 1.16.4 which is incompatible.
# pandas 1.3.5 requires numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10", but you have numpy 1.16.4 which is incompatible.
# kapre 0.3.7 requires numpy>=1.18.5, but you have numpy 1.16.4 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# jaxlib 0.3.7+cuda11.cudnn805 requires numpy>=1.19, but you have numpy 1.16.4 which is incompatible.
# jax 0.3.8 requires numpy>=1.19, but you have numpy 1.16.4 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# cupy-cuda111 9.4.0 requires numpy<1.24,>=1.17, but you have numpy 1.16.4 which is incompatible.
# astropy 4.3.1 requires numpy>=1.17, but you have numpy 1.16.4 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed numpy-1.16.4

# %%
# %cd /content/stylegan2-ada
# Out:
# /content/stylegan2-ada

# %%
# output directory
output_dir = '/content/' + dataset_name +'1'+ "/"

# config
config = "auto"

# gamma
gamma = 1

#how often should the model generate samples and a .pkl file
snapshot_count = 1

#should the images be mirrored left to right?
mirrored = True
#should the images be mirrored top to bottom?
mirroredY = False

#metrics? 
metric_list = None
#
# this is the most important cell to update
#
# running it for the first time? set it to ffhq(+resolution)
# resuming? get the path to your latest .pkl file and use that
resume_from = "ffhq256"

# make sure there is no space in the resume path. if there is any, use a backslash character to escape
# resume_from = '/content/drive/MyDrive/Colab\ Notebooks/results/pokemon-256/00001-pokemon-256-mirror-auto1-gamma1-resumecustom/network-snapshot-000036.pkl'

#don't edit this unless you know what you're doing :)
# !python train.py --outdir={output_dir} \
                 --cfg={config} \
                 --snap={snapshot_count} \
                 --data=/content/datasets/{dataset_name} \
                 --mirror={mirrored} --mirrory={mirroredY} \
                 --gamma={gamma} \
                 --metrics={metric_list} \
                 --resume={resume_from}
# Out:
# Training options:
# {
#   "G_args": {
#     "func_name": "training.networks.G_main",
#     "fmap_base": 8192,
#     "fmap_max": 512,
#     "mapping_layers": 2,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "D_args": {
#     "func_name": "training.networks.D_main",
#     "mbstd_group_size": 4,
#     "fmap_base": 8192,
#     "fmap_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.0025
#   },
#   "D_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.0025
#   },
#   "loss_args": {
#     "func_name": "training.loss.stylegan2",
#     "r1_gamma": 1.0
#   },
#   "augment_args": {
#     "class_name": "training.augment.AdaptiveAugment",
#     "tune_heuristic": "rt",
#     "tune_target": 0.6,
#     "apply_func": "training.augment.augment_pipeline",
#     "apply_args": {
#       "xflip": 1,
#       "rotate90": 1,
#       "xint": 1,
#       "scale": 1,
#       "rotate": 1,
#       "aniso": 1,
#       "xfrac": 1,
#       "brightness": 1,
#       "contrast": 1,
#       "lumaflip": 1,
#       "hue": 1,
#       "saturation": 1
#     },
#     "tune_kimg": 100
#   },
#   "num_gpus": 1,
#   "image_snapshot_ticks": 1,
#   "network_snapshot_ticks": 1,
#   "train_dataset_args": {
#     "path": "/content/datasets/\uc9c0\ube0c\ub9ac",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 256,
#     "mirror_augment": true,
#     "mirror_augment_v": false
#   },
#   "metric_arg_list": [],
#   "metric_dataset_args": {
#     "path": "/content/datasets/\uc9c0\ube0c\ub9ac",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 256,
#     "mirror_augment": true,
#     "mirror_augment_v": false
#   },
#   "total_kimg": 25000,
#   "minibatch_size": 16,
#   "minibatch_gpu": 16,
#   "G_smoothing_kimg": 5.0,
#   "G_smoothing_rampup": null,
#   "resume_pkl": "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl",
#   "run_dir": "/content/\uc9c0\ube0c\ub9ac1/00000-\uc9c0\ube0c\ub9ac-mirror-auto1-gamma1-resumeffhq256"
# }
#
# Output directory:  /content/지브리1/00000-지브리-mirror-auto1-gamma1-resumeffhq256
# Training data:     /content/datasets/지브리
# Training length:   25000 kimg
# Resolution:        256
# Number of GPUs:    1
#
# Creating output directory...
# Loading training set...
# Image shape: [3, 256, 256]
# Label shape: [0]
#
# Constructing networks...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
# Resuming from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl"
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada/pretrained/transfer-learning-source-nets/ffhq-res256-mirror-paper256-noaug.pkl ... done
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# epochs                        1         ()                  ()
# epochs_1                      1         ()                  ()
# G_mapping/Normalize           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 14, 512)        -
# dlatent_avg                   -         (512,)              -
# Truncation/Lerp               -         (?, 14, 512)        -
# G_synthesis/4x4/Const         8192      (?, 512, 4, 4)      (1, 512, 4, 4)
# G_synthesis/4x4/Conv          2622465   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB         264195    (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2622465   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Upsample      -         (?, 3, 8, 8)        -
# G_synthesis/8x8/ToRGB         264195    (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up    2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2622465   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Upsample    -         (?, 3, 16, 16)      -
# G_synthesis/16x16/ToRGB       264195    (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up    2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2622465   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Upsample    -         (?, 3, 32, 32)      -
# G_synthesis/32x32/ToRGB       264195    (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up    1442561   (?, 256, 64, 64)    (3, 3, 512, 256)
# G_synthesis/64x64/Conv1       721409    (?, 256, 64, 64)    (3, 3, 256, 256)
# G_synthesis/64x64/Upsample    -         (?, 3, 64, 64)      -
# G_synthesis/64x64/ToRGB       132099    (?, 3, 64, 64)      (1, 1, 256, 3)
# G_synthesis/128x128/Conv0_up  426369    (?, 128, 128, 128)  (3, 3, 256, 128)
# G_synthesis/128x128/Conv1     213249    (?, 128, 128, 128)  (3, 3, 128, 128)
# G_synthesis/128x128/Upsample  -         (?, 3, 128, 128)    -
# G_synthesis/128x128/ToRGB     66051     (?, 3, 128, 128)    (1, 1, 128, 3)
# G_synthesis/256x256/Conv0_up  139457    (?, 64, 256, 256)   (3, 3, 128, 64)
# G_synthesis/256x256/Conv1     69761     (?, 64, 256, 256)   (3, 3, 64, 64)
# G_synthesis/256x256/Upsample  -         (?, 3, 256, 256)    -
# G_synthesis/256x256/ToRGB     33027     (?, 3, 256, 256)    (1, 1, 64, 3)
# ---                           ---       ---                 ---
# Total                         23191524
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 256, 256)    -
# labels_in            -         (?, 0)              -
# 256x256/FromRGB      256       (?, 64, 256, 256)   (1, 1, 3, 64)
# 256x256/Conv0        36928     (?, 64, 256, 256)   (3, 3, 64, 64)
# 256x256/Conv1_down   73856     (?, 128, 128, 128)  (3, 3, 64, 128)
# 256x256/Skip         8192      (?, 128, 128, 128)  (1, 1, 64, 128)
# 128x128/Conv0        147584    (?, 128, 128, 128)  (3, 3, 128, 128)
# 128x128/Conv1_down   295168    (?, 256, 64, 64)    (3, 3, 128, 256)
# 128x128/Skip         32768     (?, 256, 64, 64)    (1, 1, 128, 256)
# 64x64/Conv0          590080    (?, 256, 64, 64)    (3, 3, 256, 256)
# 64x64/Conv1_down     1180160   (?, 512, 32, 32)    (3, 3, 256, 512)
# 64x64/Skip           131072    (?, 512, 32, 32)    (1, 1, 256, 512)
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 32x32/Skip           262144    (?, 512, 16, 16)    (1, 1, 512, 512)
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 16x16/Skip           262144    (?, 512, 8, 8)      (1, 1, 512, 512)
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
# 8x8/Skip             262144    (?, 512, 4, 4)      (1, 1, 512, 512)
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
# Output               513       (?, 1)              (512, 1)
# ---                  ---       ---                 ---
# Total                24001089
#
# Exporting sample images...
# Replicating networks across 1 GPUs...
# Initializing augmentations...
# Setting up optimizers...
# Constructing training graph...
# Finalizing training ops...
# Initializing metrics...
# Training for 25000 kimg...
#
# tick 0     kimg 0.1      time 1m 43s       sec/tick 15.8    sec/kimg 246.32  maintenance 87.2   gpumem 7.2   augment 0.000
# tick 1     kimg 4.1      time 6m 40s       sec/tick 281.3   sec/kimg 69.76   maintenance 15.3   gpumem 7.2   augment 0.033
# tick 2     kimg 8.1      time 11m 28s      sec/tick 282.5   sec/kimg 70.06   maintenance 5.6    gpumem 7.2   augment 0.069
# tick 3     kimg 12.2     time 16m 16s      sec/tick 283.4   sec/kimg 70.29   maintenance 5.5    gpumem 7.2   augment 0.103
# tick 4     kimg 16.2     time 21m 06s      sec/tick 283.9   sec/kimg 70.41   maintenance 5.4    gpumem 7.2   augment 0.134
# tick 5     kimg 20.2     time 25m 55s      sec/tick 284.0   sec/kimg 70.43   maintenance 5.4    gpumem 7.2   augment 0.171
# tick 6     kimg 24.3     time 30m 45s      sec/tick 284.9   sec/kimg 70.65   maintenance 5.4    gpumem 7.2   augment 0.204
# tick 7     kimg 28.3     time 35m 36s      sec/tick 285.2   sec/kimg 70.72   maintenance 5.4    gpumem 7.2   augment 0.237
# tick 8     kimg 32.3     time 40m 27s      sec/tick 285.7   sec/kimg 70.85   maintenance 5.4    gpumem 7.2   augment 0.268
# tick 9     kimg 36.4     time 45m 18s      sec/tick 285.5   sec/kimg 70.82   maintenance 5.4    gpumem 7.2   augment 0.294
# tick 10    kimg 40.4     time 50m 10s      sec/tick 286.4   sec/kimg 71.03   maintenance 5.4    gpumem 7.2   augment 0.319
# tick 11    kimg 44.4     time 55m 02s      sec/tick 286.6   sec/kimg 71.07   maintenance 5.4    gpumem 7.2   augment 0.341
# tick 12    kimg 48.4     time 59m 54s      sec/tick 287.0   sec/kimg 71.19   maintenance 5.4    gpumem 7.2   augment 0.362
# tick 13    kimg 52.5     time 1h 04m 47s   sec/tick 287.0   sec/kimg 71.18   maintenance 5.4    gpumem 7.2   augment 0.383
# tick 14    kimg 56.5     time 1h 09m 40s   sec/tick 287.8   sec/kimg 71.38   maintenance 5.5    gpumem 7.2   augment 0.402
# tick 15    kimg 60.5     time 1h 14m 33s   sec/tick 287.8   sec/kimg 71.39   maintenance 5.4    gpumem 7.2   augment 0.418
# tick 16    kimg 64.6     time 1h 19m 27s   sec/tick 288.1   sec/kimg 71.45   maintenance 5.4    gpumem 7.2   augment 0.433
# tick 17    kimg 68.6     time 1h 24m 20s   sec/tick 287.6   sec/kimg 71.33   maintenance 5.4    gpumem 7.2   augment 0.450
# tick 18    kimg 72.6     time 1h 29m 13s   sec/tick 288.2   sec/kimg 71.48   maintenance 5.4    gpumem 7.2   augment 0.465
# tick 19    kimg 76.7     time 1h 34m 07s   sec/tick 288.6   sec/kimg 71.58   maintenance 5.4    gpumem 7.2   augment 0.478
# tick 20    kimg 80.7     time 1h 39m 01s   sec/tick 288.3   sec/kimg 71.50   maintenance 5.4    gpumem 7.2   augment 0.492
# tick 21    kimg 84.7     time 1h 43m 55s   sec/tick 288.1   sec/kimg 71.46   maintenance 5.4    gpumem 7.2   augment 0.496
# tick 22    kimg 88.8     time 1h 48m 49s   sec/tick 288.6   sec/kimg 71.58   maintenance 5.4    gpumem 7.2   augment 0.508
# tick 23    kimg 92.8     time 1h 53m 43s   sec/tick 288.8   sec/kimg 71.62   maintenance 5.4    gpumem 7.2   augment 0.522
# tick 24    kimg 96.8     time 1h 58m 37s   sec/tick 288.8   sec/kimg 71.63   maintenance 5.4    gpumem 7.2   augment 0.530
# tick 25    kimg 100.9    time 2h 03m 31s   sec/tick 288.5   sec/kimg 71.54   maintenance 5.4    gpumem 7.2   augment 0.541
# tick 26    kimg 104.9    time 2h 08m 26s   sec/tick 289.2   sec/kimg 71.74   maintenance 5.4    gpumem 7.2   augment 0.550
# tick 27    kimg 108.9    time 2h 13m 20s   sec/tick 289.4   sec/kimg 71.77   maintenance 5.4    gpumem 7.2   augment 0.556
# tick 28    kimg 113.0    time 2h 18m 15s   sec/tick 289.4   sec/kimg 71.78   maintenance 5.4    gpumem 7.2   augment 0.562
# tick 29    kimg 117.0    time 2h 23m 10s   sec/tick 289.1   sec/kimg 71.70   maintenance 5.4    gpumem 7.2   augment 0.561
# tick 30    kimg 121.0    time 2h 28m 05s   sec/tick 289.5   sec/kimg 71.79   maintenance 5.4    gpumem 7.2   augment 0.567
# tick 31    kimg 125.1    time 2h 32m 59s   sec/tick 289.3   sec/kimg 71.74   maintenance 5.4    gpumem 7.2   augment 0.570
# tick 32    kimg 129.1    time 2h 37m 54s   sec/tick 289.4   sec/kimg 71.77   maintenance 5.4    gpumem 7.2   augment 0.579
# tick 33    kimg 133.1    time 2h 42m 48s   sec/tick 289.0   sec/kimg 71.68   maintenance 5.4    gpumem 7.2   augment 0.580
# tick 34    kimg 137.2    time 2h 47m 43s   sec/tick 289.5   sec/kimg 71.81   maintenance 5.4    gpumem 7.2   augment 0.589
# tick 35    kimg 141.2    time 2h 52m 38s   sec/tick 289.5   sec/kimg 71.80   maintenance 5.4    gpumem 7.2   augment 0.588
# tick 36    kimg 145.2    time 2h 57m 33s   sec/tick 289.4   sec/kimg 71.78   maintenance 5.4    gpumem 7.2   augment 0.595
# tick 37    kimg 149.2    time 3h 02m 28s   sec/tick 289.2   sec/kimg 71.73   maintenance 5.4    gpumem 7.2   augment 0.600
# tick 38    kimg 153.3    time 3h 07m 23s   sec/tick 289.9   sec/kimg 71.90   maintenance 5.4    gpumem 7.2   augment 0.604
# tick 39    kimg 157.3    time 3h 12m 18s   sec/tick 290.0   sec/kimg 71.93   maintenance 5.4    gpumem 7.2   augment 0.605
# tick 40    kimg 161.3    time 3h 17m 14s   sec/tick 289.8   sec/kimg 71.88   maintenance 5.4    gpumem 7.2   augment 0.598
# tick 41    kimg 165.4    time 3h 22m 08s   sec/tick 289.3   sec/kimg 71.76   maintenance 5.4    gpumem 7.2   augment 0.597
# tick 42    kimg 169.4    time 3h 27m 03s   sec/tick 289.8   sec/kimg 71.87   maintenance 5.4    gpumem 7.2   augment 0.604
# tick 43    kimg 173.4    time 3h 31m 59s   sec/tick 289.8   sec/kimg 71.88   maintenance 5.4    gpumem 7.2   augment 0.605
# tick 44    kimg 177.5    time 3h 36m 54s   sec/tick 289.8   sec/kimg 71.88   maintenance 5.4    gpumem 7.2   augment 0.605
# tick 45    kimg 181.5    time 3h 41m 48s   sec/tick 289.1   sec/kimg 71.70   maintenance 5.4    gpumem 7.2   augment 0.606
# tick 46    kimg 185.5    time 3h 46m 44s   sec/tick 289.8   sec/kimg 71.88   maintenance 5.4    gpumem 7.2   augment 0.609
# tick 47    kimg 189.6    time 3h 51m 39s   sec/tick 289.9   sec/kimg 71.89   maintenance 5.4    gpumem 7.2   augment 0.612
# tick 48    kimg 193.6    time 3h 56m 34s   sec/tick 289.7   sec/kimg 71.84   maintenance 5.4    gpumem 7.2   augment 0.612
# tick 49    kimg 197.6    time 4h 01m 29s   sec/tick 289.5   sec/kimg 71.80   maintenance 5.4    gpumem 7.2   augment 0.618
# tick 50    kimg 201.7    time 4h 06m 24s   sec/tick 290.0   sec/kimg 71.93   maintenance 5.4    gpumem 7.2   augment 0.623
# tick 51    kimg 205.7    time 4h 11m 20s   sec/tick 290.2   sec/kimg 71.97   maintenance 5.4    gpumem 7.2   augment 0.627
# tick 52    kimg 209.7    time 4h 16m 16s   sec/tick 290.2   sec/kimg 71.99   maintenance 5.4    gpumem 7.2   augment 0.628
# tick 53    kimg 213.8    time 4h 21m 11s   sec/tick 289.8   sec/kimg 71.87   maintenance 5.4    gpumem 7.2   augment 0.629
# tick 54    kimg 217.8    time 4h 26m 06s   sec/tick 290.1   sec/kimg 71.94   maintenance 5.4    gpumem 7.2   augment 0.631
# tick 55    kimg 221.8    time 4h 31m 02s   sec/tick 290.1   sec/kimg 71.94   maintenance 5.4    gpumem 7.2   augment 0.638
# tick 56    kimg 225.9    time 4h 35m 57s   sec/tick 290.1   sec/kimg 71.95   maintenance 5.4    gpumem 7.2   augment 0.639
# tick 57    kimg 229.9    time 4h 40m 52s   sec/tick 289.6   sec/kimg 71.82   maintenance 5.4    gpumem 7.2   augment 0.639
# tick 58    kimg 233.9    time 4h 45m 48s   sec/tick 290.0   sec/kimg 71.93   maintenance 5.4    gpumem 7.2   augment 0.639
# tick 59    kimg 238.0    time 4h 50m 43s   sec/tick 290.0   sec/kimg 71.93   maintenance 5.4    gpumem 7.2   augment 0.636
# tick 60    kimg 242.0    time 4h 55m 39s   sec/tick 290.0   sec/kimg 71.93   maintenance 5.4    gpumem 7.2   augment 0.636
# tick 61    kimg 246.0    time 5h 00m 34s   sec/tick 289.7   sec/kimg 71.84   maintenance 5.4    gpumem 7.2   augment 0.641
# tick 62    kimg 250.0    time 5h 05m 29s   sec/tick 290.2   sec/kimg 71.98   maintenance 5.4    gpumem 7.2   augment 0.639
# tick 63    kimg 254.1    time 5h 10m 25s   sec/tick 290.2   sec/kimg 71.98   maintenance 5.4    gpumem 7.2   augment 0.648
# tick 64    kimg 258.1    time 5h 15m 21s   sec/tick 290.5   sec/kimg 72.04   maintenance 5.4    gpumem 7.2   augment 0.649
# tick 65    kimg 262.1    time 5h 20m 16s   sec/tick 290.0   sec/kimg 71.92   maintenance 5.4    gpumem 7.2   augment 0.651
# tick 66    kimg 266.2    time 5h 25m 12s   sec/tick 290.7   sec/kimg 72.10   maintenance 5.5    gpumem 7.2   augment 0.648
# tick 67    kimg 270.2    time 5h 30m 08s   sec/tick 290.5   sec/kimg 72.05   maintenance 5.5    gpumem 7.2   augment 0.653
# tick 68    kimg 274.2    time 5h 35m 04s   sec/tick 290.6   sec/kimg 72.06   maintenance 5.4    gpumem 7.2   augment 0.659
# tick 69    kimg 278.3    time 5h 40m 00s   sec/tick 290.0   sec/kimg 71.93   maintenance 5.5    gpumem 7.2   augment 0.661
# tick 70    kimg 282.3    time 5h 44m 56s   sec/tick 290.7   sec/kimg 72.09   maintenance 5.4    gpumem 7.2   augment 0.669
# tick 71    kimg 286.3    time 5h 49m 52s   sec/tick 290.4   sec/kimg 72.04   maintenance 5.4    gpumem 7.2   augment 0.670
# tick 72    kimg 290.4    time 5h 54m 48s   sec/tick 290.5   sec/kimg 72.05   maintenance 5.4    gpumem 7.2   augment 0.668
# tick 73    kimg 294.4    time 5h 59m 43s   sec/tick 290.0   sec/kimg 71.92   maintenance 5.4    gpumem 7.2   augment 0.665
# tick 74    kimg 298.4    time 6h 04m 39s   sec/tick 290.5   sec/kimg 72.06   maintenance 5.4    gpumem 7.2   augment 0.663
# tick 75    kimg 302.5    time 6h 09m 35s   sec/tick 290.4   sec/kimg 72.03   maintenance 5.4    gpumem 7.2   augment 0.668
# tick 76    kimg 306.5    time 6h 14m 31s   sec/tick 290.6   sec/kimg 72.08   maintenance 5.4    gpumem 7.2   augment 0.669
# tick 77    kimg 310.5    time 6h 19m 27s   sec/tick 290.2   sec/kimg 71.99   maintenance 5.5    gpumem 7.2   augment 0.671
# tick 78    kimg 314.6    time 6h 24m 23s   sec/tick 290.5   sec/kimg 72.04   maintenance 5.6    gpumem 7.2   augment 0.669
# tick 79    kimg 318.6    time 6h 29m 19s   sec/tick 290.6   sec/kimg 72.07   maintenance 5.5    gpumem 7.2   augment 0.670
# tick 80    kimg 322.6    time 6h 34m 15s   sec/tick 290.3   sec/kimg 72.00   maintenance 5.6    gpumem 7.2   augment 0.669
# tick 81    kimg 326.7    time 6h 39m 10s   sec/tick 289.8   sec/kimg 71.88   maintenance 5.4    gpumem 7.2   augment 0.673
# tick 82    kimg 330.7    time 6h 44m 06s   sec/tick 290.6   sec/kimg 72.09   maintenance 5.4    gpumem 7.2   augment 0.678
# tick 83    kimg 334.7    time 6h 49m 02s   sec/tick 290.5   sec/kimg 72.04   maintenance 5.4    gpumem 7.2   augment 0.682
# tick 84    kimg 338.8    time 6h 53m 58s   sec/tick 290.6   sec/kimg 72.07   maintenance 5.4    gpumem 7.2   augment 0.687
# tick 85    kimg 342.8    time 6h 58m 53s   sec/tick 290.0   sec/kimg 71.92   maintenance 5.4    gpumem 7.2   augment 0.694
# tick 86    kimg 346.8    time 7h 03m 49s   sec/tick 290.8   sec/kimg 72.11   maintenance 5.4    gpumem 7.2   augment 0.698
# tick 87    kimg 350.8    time 7h 08m 46s   sec/tick 290.9   sec/kimg 72.15   maintenance 5.4    gpumem 7.2   augment 0.697
# tick 88    kimg 354.9    time 7h 13m 42s   sec/tick 290.9   sec/kimg 72.14   maintenance 5.4    gpumem 7.2   augment 0.698
# tick 89    kimg 358.9    time 7h 18m 38s   sec/tick 290.1   sec/kimg 71.95   maintenance 5.4    gpumem 7.2   augment 0.701
# tick 90    kimg 362.9    time 7h 23m 34s   sec/tick 290.7   sec/kimg 72.09   maintenance 5.4    gpumem 7.2   augment 0.704
# tick 91    kimg 367.0    time 7h 28m 30s   sec/tick 290.8   sec/kimg 72.13   maintenance 5.4    gpumem 7.2   augment 0.707
# tick 92    kimg 371.0    time 7h 33m 26s   sec/tick 290.8   sec/kimg 72.12   maintenance 5.4    gpumem 7.2   augment 0.712
# tick 93    kimg 375.0    time 7h 38m 22s   sec/tick 290.4   sec/kimg 72.04   maintenance 5.4    gpumem 7.2   augment 0.715
# tick 94    kimg 379.1    time 7h 43m 18s   sec/tick 290.7   sec/kimg 72.11   maintenance 5.4    gpumem 7.2   augment 0.716
# tick 95    kimg 383.1    time 7h 48m 14s   sec/tick 290.7   sec/kimg 72.11   maintenance 5.4    gpumem 7.2   augment 0.715
# tick 96    kimg 387.1    time 7h 53m 11s   sec/tick 290.9   sec/kimg 72.14   maintenance 5.4    gpumem 7.2   augment 0.712
# tick 97    kimg 391.2    time 7h 58m 06s   sec/tick 290.3   sec/kimg 72.01   maintenance 5.4    gpumem 7.2   augment 0.708
# tick 98    kimg 395.2    time 8h 03m 02s   sec/tick 290.8   sec/kimg 72.11   maintenance 5.4    gpumem 7.2   augment 0.709
# tick 99    kimg 399.2    time 8h 07m 59s   sec/tick 290.9   sec/kimg 72.16   maintenance 5.4    gpumem 7.2   augment 0.707
# tick 100   kimg 403.3    time 8h 12m 55s   sec/tick 290.9   sec/kimg 72.14   maintenance 5.4    gpumem 7.2   augment 0.713
# tick 101   kimg 407.3    time 8h 17m 51s   sec/tick 290.6   sec/kimg 72.08   maintenance 5.4    gpumem 7.2   augment 0.708
# tick 102   kimg 411.3    time 8h 22m 48s   sec/tick 291.1   sec/kimg 72.20   maintenance 5.4    gpumem 7.2   augment 0.712
# tick 103   kimg 415.4    time 8h 27m 44s   sec/tick 291.1   sec/kimg 72.20   maintenance 5.4    gpumem 7.2   augment 0.708
# tick 104   kimg 419.4    time 8h 32m 40s   sec/tick 290.7   sec/kimg 72.09   maintenance 5.4    gpumem 7.2   augment 0.707
# tick 105   kimg 423.4    time 8h 37m 36s   sec/tick 290.3   sec/kimg 72.01   maintenance 5.4    gpumem 7.2   augment 0.714
# tick 106   kimg 427.5    time 8h 42m 32s   sec/tick 290.9   sec/kimg 72.14   maintenance 5.4    gpumem 7.2   augment 0.716
# tick 107   kimg 431.5    time 8h 47m 29s   sec/tick 290.8   sec/kimg 72.12   maintenance 5.4    gpumem 7.2   augment 0.717
# tick 108   kimg 435.5    time 8h 52m 25s   sec/tick 290.8   sec/kimg 72.13   maintenance 5.4    gpumem 7.2   augment 0.731
# tick 109   kimg 439.6    time 8h 57m 21s   sec/tick 290.6   sec/kimg 72.07   maintenance 5.4    gpumem 7.2   augment 0.730
# tick 110   kimg 443.6    time 9h 02m 17s   sec/tick 291.3   sec/kimg 72.25   maintenance 5.4    gpumem 7.2   augment 0.735
# tick 111   kimg 447.6    time 9h 07m 14s   sec/tick 291.4   sec/kimg 72.27   maintenance 5.4    gpumem 7.2   augment 0.737
# tick 112   kimg 451.6    time 9h 12m 11s   sec/tick 291.2   sec/kimg 72.23   maintenance 5.4    gpumem 7.2   augment 0.739
# tick 113   kimg 455.7    time 9h 17m 07s   sec/tick 290.9   sec/kimg 72.15   maintenance 5.4    gpumem 7.2   augment 0.744
# tick 114   kimg 459.7    time 9h 22m 04s   sec/tick 291.3   sec/kimg 72.24   maintenance 5.4    gpumem 7.2   augment 0.751
# tick 115   kimg 463.7    time 9h 27m 01s   sec/tick 291.4   sec/kimg 72.28   maintenance 5.4    gpumem 7.2   augment 0.749
# tick 116   kimg 467.8    time 9h 31m 57s   sec/tick 291.3   sec/kimg 72.24   maintenance 5.4    gpumem 7.2   augment 0.746
# tick 117   kimg 471.8    time 9h 36m 53s   sec/tick 290.5   sec/kimg 72.05   maintenance 5.4    gpumem 7.2   augment 0.748
# tick 118   kimg 475.8    time 9h 41m 50s   sec/tick 291.3   sec/kimg 72.26   maintenance 5.4    gpumem 7.2   augment 0.750
# tick 119   kimg 479.9    time 9h 46m 47s   sec/tick 291.4   sec/kimg 72.28   maintenance 5.4    gpumem 7.2   augment 0.749
# tick 120   kimg 483.9    time 9h 51m 44s   sec/tick 291.6   sec/kimg 72.31   maintenance 5.4    gpumem 7.2   augment 0.745
# tick 121   kimg 487.9    time 9h 56m 40s   sec/tick 291.0   sec/kimg 72.17   maintenance 5.4    gpumem 7.2   augment 0.749
# tick 122   kimg 492.0    time 10h 01m 37s  sec/tick 291.4   sec/kimg 72.28   maintenance 5.4    gpumem 7.2   augment 0.755
# tick 123   kimg 496.0    time 10h 06m 34s  sec/tick 291.6   sec/kimg 72.32   maintenance 5.4    gpumem 7.2   augment 0.761
# tick 124   kimg 500.0    time 10h 11m 31s  sec/tick 291.4   sec/kimg 72.28   maintenance 5.4    gpumem 7.2   augment 0.755
# tick 125   kimg 504.1    time 10h 16m 27s  sec/tick 291.0   sec/kimg 72.17   maintenance 5.4    gpumem 7.2   augment 0.758
# tick 126   kimg 508.1    time 10h 21m 24s  sec/tick 291.4   sec/kimg 72.26   maintenance 5.4    gpumem 7.2   augment 0.756
# tick 127   kimg 512.1    time 10h 26m 21s  sec/tick 291.4   sec/kimg 72.28   maintenance 5.4    gpumem 7.2   augment 0.761
# tick 128   kimg 516.2    time 10h 31m 18s  sec/tick 291.6   sec/kimg 72.31   maintenance 5.4    gpumem 7.2   augment 0.760
# tick 129   kimg 520.2    time 10h 36m 14s  sec/tick 290.8   sec/kimg 72.13   maintenance 5.4    gpumem 7.2   augment 0.760
# tick 130   kimg 524.2    time 10h 41m 11s  sec/tick 291.2   sec/kimg 72.23   maintenance 5.4    gpumem 7.2   augment 0.759
# tick 131   kimg 528.3    time 10h 46m 08s  sec/tick 291.3   sec/kimg 72.25   maintenance 5.4    gpumem 7.2   augment 0.760
# tick 132   kimg 532.3    time 10h 51m 04s  sec/tick 291.4   sec/kimg 72.27   maintenance 5.4    gpumem 7.2   augment 0.764
# tick 133   kimg 536.3    time 10h 56m 01s  sec/tick 290.9   sec/kimg 72.15   maintenance 5.4    gpumem 7.2   augment 0.769
# tick 134   kimg 540.4    time 11h 00m 58s  sec/tick 291.4   sec/kimg 72.28   maintenance 5.4    gpumem 7.2   augment 0.774
# tick 135   kimg 544.4    time 11h 05m 55s  sec/tick 291.7   sec/kimg 72.34   maintenance 5.4    gpumem 7.2   augment 0.778
# tick 136   kimg 548.4    time 11h 10m 52s  sec/tick 291.8   sec/kimg 72.37   maintenance 5.4    gpumem 7.2   augment 0.780
# tick 137   kimg 552.4    time 11h 15m 49s  sec/tick 291.3   sec/kimg 72.25   maintenance 5.4    gpumem 7.2   augment 0.780
# tick 138   kimg 556.5    time 11h 20m 46s  sec/tick 291.7   sec/kimg 72.34   maintenance 5.5    gpumem 7.2   augment 0.785
# tick 139   kimg 560.5    time 11h 25m 43s  sec/tick 291.7   sec/kimg 72.34   maintenance 5.4    gpumem 7.2   augment 0.784
# tick 140   kimg 564.5    time 11h 30m 40s  sec/tick 291.8   sec/kimg 72.36   maintenance 5.4    gpumem 7.2   augment 0.787
# tick 141   kimg 568.6    time 11h 35m 36s  sec/tick 290.9   sec/kimg 72.16   maintenance 5.4    gpumem 7.2   augment 0.784
# tick 142   kimg 572.6    time 11h 40m 34s  sec/tick 291.8   sec/kimg 72.36   maintenance 5.4    gpumem 7.2   augment 0.794
# tick 143   kimg 576.6    time 11h 45m 31s  sec/tick 291.8   sec/kimg 72.37   maintenance 5.4    gpumem 7.2   augment 0.796
# tick 144   kimg 580.7    time 11h 50m 28s  sec/tick 291.7   sec/kimg 72.34   maintenance 5.4    gpumem 7.2   augment 0.805
# tick 145   kimg 584.7    time 11h 55m 25s  sec/tick 291.3   sec/kimg 72.24   maintenance 5.4    gpumem 7.2   augment 0.803
# tick 146   kimg 588.7    time 12h 00m 22s  sec/tick 291.8   sec/kimg 72.37   maintenance 5.4    gpumem 7.2   augment 0.806
# tick 147   kimg 592.8    time 12h 05m 19s  sec/tick 291.7   sec/kimg 72.35   maintenance 5.4    gpumem 7.2   augment 0.802
# tick 148   kimg 596.8    time 12h 10m 17s  sec/tick 292.1   sec/kimg 72.45   maintenance 5.4    gpumem 7.2   augment 0.803
# tick 149   kimg 600.8    time 12h 15m 13s  sec/tick 291.5   sec/kimg 72.29   maintenance 5.5    gpumem 7.2   augment 0.804
# tick 150   kimg 604.9    time 12h 20m 11s  sec/tick 292.0   sec/kimg 72.43   maintenance 5.4    gpumem 7.2   augment 0.795
# tick 151   kimg 608.9    time 12h 25m 08s  sec/tick 291.9   sec/kimg 72.40   maintenance 5.4    gpumem 7.2   augment 0.797
# tick 152   kimg 612.9    time 12h 30m 06s  sec/tick 291.9   sec/kimg 72.39   maintenance 5.4    gpumem 7.2   augment 0.806
# tick 153   kimg 617.0    time 12h 35m 03s  sec/tick 291.5   sec/kimg 72.30   maintenance 5.5    gpumem 7.2   augment 0.815
# tick 154   kimg 621.0    time 12h 40m 00s  sec/tick 291.8   sec/kimg 72.37   maintenance 5.4    gpumem 7.2   augment 0.810
# tick 155   kimg 625.0    time 12h 44m 57s  sec/tick 291.8   sec/kimg 72.37   maintenance 5.6    gpumem 7.2   augment 0.819
# tick 156   kimg 629.1    time 12h 49m 54s  sec/tick 291.8   sec/kimg 72.38   maintenance 5.4    gpumem 7.2   augment 0.820
# tick 157   kimg 633.1    time 12h 54m 52s  sec/tick 291.7   sec/kimg 72.35   maintenance 5.4    gpumem 7.2   augment 0.815
# tick 158   kimg 637.1    time 12h 59m 49s  sec/tick 291.9   sec/kimg 72.38   maintenance 5.5    gpumem 7.2   augment 0.812
# tick 159   kimg 641.2    time 13h 04m 46s  sec/tick 292.0   sec/kimg 72.43   maintenance 5.4    gpumem 7.2   augment 0.810
# tick 160   kimg 645.2    time 13h 09m 44s  sec/tick 292.2   sec/kimg 72.46   maintenance 5.4    gpumem 7.2   augment 0.812
# tick 161   kimg 649.2    time 13h 14m 41s  sec/tick 291.6   sec/kimg 72.33   maintenance 5.4    gpumem 7.2   augment 0.816
# tick 162   kimg 653.2    time 13h 19m 39s  sec/tick 292.1   sec/kimg 72.44   maintenance 5.4    gpumem 7.2   augment 0.823
# tick 163   kimg 657.3    time 13h 24m 36s  sec/tick 292.1   sec/kimg 72.46   maintenance 5.4    gpumem 7.2   augment 0.830
# tick 164   kimg 661.3    time 13h 29m 34s  sec/tick 292.3   sec/kimg 72.49   maintenance 5.4    gpumem 7.2   augment 0.833
# tick 165   kimg 665.3    time 13h 34m 31s  sec/tick 292.0   sec/kimg 72.43   maintenance 5.6    gpumem 7.2   augment 0.836
# tick 166   kimg 669.4    time 13h 39m 30s  sec/tick 292.7   sec/kimg 72.58   maintenance 5.4    gpumem 7.2   augment 0.837
# tick 167   kimg 673.4    time 13h 44m 28s  sec/tick 292.6   sec/kimg 72.56   maintenance 5.4    gpumem 7.2   augment 0.836
# tick 168   kimg 677.4    time 13h 49m 25s  sec/tick 292.5   sec/kimg 72.54   maintenance 5.4    gpumem 7.2   augment 0.844
# tick 169   kimg 681.5    time 13h 54m 23s  sec/tick 292.0   sec/kimg 72.43   maintenance 5.5    gpumem 7.2   augment 0.843
# tick 170   kimg 685.5    time 13h 59m 21s  sec/tick 292.5   sec/kimg 72.54   maintenance 5.4    gpumem 7.2   augment 0.847
# tick 171   kimg 689.5    time 14h 04m 19s  sec/tick 292.7   sec/kimg 72.59   maintenance 5.5    gpumem 7.2   augment 0.848
# tick 172   kimg 693.6    time 14h 09m 17s  sec/tick 292.9   sec/kimg 72.65   maintenance 5.5    gpumem 7.2   augment 0.845
# tick 173   kimg 697.6    time 14h 14m 15s  sec/tick 292.2   sec/kimg 72.47   maintenance 5.5    gpumem 7.2   augment 0.847
# tick 174   kimg 701.6    time 14h 19m 13s  sec/tick 292.7   sec/kimg 72.60   maintenance 5.5    gpumem 7.2   augment 0.845
# Traceback (most recent call last):
#   File "train.py", line 645, in <module>
#     main()
#   File "train.py", line 637, in main
#     run_training(**vars(args))
#   File "train.py", line 522, in run_training
#     training_loop.training_loop(**training_options)
#   File "/content/stylegan2-ada/training/training_loop.py", line 255, in training_loop
#     tflib.run([D_train_op, Gs_update_op, Gs_epochs_op], {Gs_beta_in: Gs_beta, Gs_epochs: epochs})
#   File "/content/stylegan2-ada/dnnlib/tflib/tfutil.py", line 33, in run
#     return tf.get_default_session().run(*args, **kwargs)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 956, in run
#     run_metadata_ptr)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1180, in _run
#     feed_dict_tensor, options, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1359, in _do_run
#     run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1365, in _do_call
#     return fn(*args)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1350, in _run_fn
#     target_list, run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1443, in _call_tf_sessionrun
#     run_metadata)
# KeyboardInterrupt
